# %% [markdown]
# <a href="https://colab.research.google.com/github/rebaloffical47/tim/blob/main/Un.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
student = { "name":"Alice", "age":20, "grade":"a"}
student["name"]
# Out:
# 'Alice'

# %%
#title year and actor
movie = {"Title":"Deadpool And Wolverine", "Year":2025, "Actor":"Ryan Renolds"}
movie["Actor"]
movie["genre"]="Adventure"
movie["Actor"]
movie["Year"]=2024
del movie ["genre"]
print(movie)
# Out:
# {'Title': 'Deadpool And Wolverine', 'Year': 2024, 'Actor': 'Ryan Renolds'}

# %%
fruits=["apple", "orange", "bannana"]
fruits.append("cherry")
newfruits = fruits+["grapes"]
fruits.insert(1,"grapes")
print(fruits)
# Out:
# ['apple', 'grapes', 'orange', 'bannana', 'cherry']

# %%
grades = {gra2des = {"stick":"92", "brick":"89", "Psuh":"97"},
          movie = {"Title":"Deadpool And Wolverine", "Year":2025, "Actor":"Ryan Renolds"}}
grades["David"]=88
grades["stick"]= 100
print(grades)
# Out:
# {'stick': 100, 'brick': '89', 'Psuh': '97', 'David': 88}

# %%
#hw
#create nested dicitonary called school where
#Each key is a class name (e.g., "Subject 1", "Subject 2")
#Each value is another dictionary containing "teacher" and "students" (a list of names)
 #Add a new class "Grade 3" with one teacher and two students. Add a new student "Frank" to "Grade 2". Print all teachers’ names using a loop. Print each class name and its student list in a neat format:
# Add a new class "Subject 3" with one teacher and two students. Add a new student "Frank" to "Grade 2". Print all teachers’ names using a loop. Print each class name and its student list in a neat format:

# %%
school = {
    "subject1": {
        "teacher": "Mr T",
        "Students": ["Bob", "Timothy", "Sam", "Carter"]
    },
    "subject2":{
        "teacher": "Mr H",
        "Students":["Tom", "Johnny", "Jim","Steve"]
    }
}
school["subject2"]["Students"].append("Frank")

# %%
# Create a queue that simulates people lining up to buy ice cream

# %%
from collections import deque


queue = deque(["jeff1", "jeff2"])
queue.append("jeff6")
print(queue)
queue.append("jeff7")
print(queue)
while queue:
  person= queue.popleft()
  print(f"{person} got icecream")
# Out:
# deque(['jeff1', 'jeff2', 'jeff6'])
# deque(['jeff1', 'jeff2', 'jeff6', 'jeff7'])
# jeff1 got icecream
# jeff2 got icecream
# jeff6 got icecream
# jeff7 got icecream

# %%
def reversed(s):
  stack=[]
  for char in s:
    stack.append(char)
  reversed_str = ""
  while stack:
    reversed_str +=stack.pop()
  return reversed_str
word = "hello"
reversed(word)
# Out:
# 'olleh'

# %%
class Node:
  def __init__(self,value):
    self.value = value
    self.next = None
class LinkedLists:
  def __init__(self):
    self.head = None
  def insertathead(self,value):
    #create a new node and insert it at the beginning
    pass
  def insertattail(self,value):
    #create a new node and insert it at the end of the list
    pass
  def search(self,value):
    #return true if the value is in the list
    pass
  def printlist(self):
    # print values like 3 -> 7 ->7 -> 10 -> none
    pass

class LinkedLists:
    def __init__(self):
        self.next = None
    def insertathead(self, value):
        new_node = Node(value)
        new_node.next = self.next
        self.next = new_node
